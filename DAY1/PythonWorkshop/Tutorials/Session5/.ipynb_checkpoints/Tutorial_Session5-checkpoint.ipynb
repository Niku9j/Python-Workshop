# %% [markdown]
# ---
# # <font color= blue > Twitter </font>
# * Twitter can also be used to retrieve information about the tweets, connections, or followers of a user, or topics trending on Twitter.
# * Information is shared on Twitter in the form of tweets. A tweet may contain photos, videos, links, and up to 140 characters of text.
# * Twitter provides several APIs (Application Programming Interfaces) to access Twitter data such as user’s profile information or tweets
# * An API request on Twitter is first authenticated using Open Authentication (OAuth). OAuth allows the users to connect to Twitter and send authorized Twitter API request.
# * For performing analysis on Twitter data, we need the package tweepy.
#
# > Commands for installing library tweepy <br>
#     > pip install tweepy
#
# <br>
# ### <font color= green > Steps for Open Authentication </font>

# %% [markdown]
# <div style="width: 800px;"> ![](1.png) </div>

# %% [markdown]
# ## <font color= blue > Collecting User's Information </font>

# %%
import tweepy

def OAuthVerifier():
    '''
    Objective: To authorize the application to access Twitter
    Input Parameter: None
    Return Value: API object
    '''
    consumerKey = 'iym0XRG0SOgyPOjmlPQgB4XrC'
    consumerSecret = 'I6gBj8RpcXJvN6xaKUUGeTkPEDpHziRXBmT9d9yG8k5Ik0H0bF'
    authorization = tweepy.OAuthHandler(consumerKey, consumerSecret)
    accessToken = '727494459118653446-XWf9MmBJmCUOM7Ic9xvoHlZCBQAWWA1'
    accessSecret = 'jl4UJPXYSC8ygV8EsyNz6fMOW2NEs9NFvJc2InyfXNvve'
    authorization.set_access_token(accessToken, accessSecret)
    api = tweepy.API(authorization)
    return api

def getUserStatistics(user):
    '''
    Objective: To get user statistics using various
            variables of the api
    Input Parameter: user - string
    Return Value: None
    '''
    print('\nName: ', user.name)
    print('Screen Name: ', user.screen_name)
    print('ID: ', user.id)
    print('Account creation date and time: ', user.created_at)
    print('Location: ', user.location)
    print('Description: ', user.description)
    print('No. of followers: ', user.followers_count)
    print('No. of friends: ', user.friends_count)
    print('No. of favourite tweets: ', user.favourites_count)
    print('No. of posted tweets: ', user.statuses_count)
    print('Associated URL: ', user.url)

def main():
    '''
    Objective: To collect user information
    Input Parameter: None
    Return Value: None
    '''
    # To print user's information
    api = OAuthVerifier()
    # Authenticated User
    user = api.me()
    getUserStatistics(user)

if __name__ == '__main__':
    main()
# Out:
# Name:  Suzzane Mathew
# Screen Name:  SuzzaneMathew
# ID:  727494459118653446
# Account creation date and time:  2016-05-03 13:46:10
# Location:  India
# Description:  A Python Programmer
# No. of followers:  4
# No. of friends:  34
# No. of favourite tweets:  0
# No. of posted tweets:  3
# Associated URL:  None
#
#
# Enter the user identification: @Sachin_RT
#
# Name:  Sachin Tendulkar
# Screen Name:  sachin_rt
# ID:  135421739
# Account creation date and time:  2010-04-21 07:42:23
# Location:  ÜT: 18.986431,72.823769
# Description:  Proud Indian
# No. of followers:  24734353
# No. of friends:  78
# No. of favourite tweets:  64
# No. of posted tweets:  2024
# Associated URL:  http://t.co/TCNcUDBwuE

# %% [markdown]
# ## <font color= blue > Collecting Followers, Friends, and Tweets of a User </font>

# %%
import tweepy

def OAuthVerifier():
    '''
    Objective: To authorize the application to access Twitter
    Input Parameter: None
    Return Value: API object
    '''
    consumerKey = 'iym0XRG0SOgyPOjmlPQgB4XrC'
    consumerSecret = 'I6gBj8RpcXJvN6xaKUUGeTkPEDpHziRXBmT9d9yG8k5Ik0H0bF'
    authorization = tweepy.OAuthHandler(consumerKey, consumerSecret)
    accessToken = '727494459118653446-XWf9MmBJmCUOM7Ic9xvoHlZCBQAWWA1'
    accessSecret = 'jl4UJPXYSC8ygV8EsyNz6fMOW2NEs9NFvJc2InyfXNvve'
    authorization.set_access_token(accessToken, accessSecret)
    api = tweepy.API(authorization)
    return api

def getUserFollowers(api):
    '''
    Objective: To get followers of the user
    Input Parameter: api - object of class API
    Return Value: None
    '''
    print('\nFollowers:')
    for follower in api.followers():
        print(follower.screen_name)
    
def getUserFriends(api):
    '''
    Objective: To get friends of the user
    Input Parameter: api - object of class API
    Return Value: None
    '''
    print('\nFriends:')
    for friend in api.friends():
        print(friend.screen_name)
        
def getUserTweets(api):
    '''
    Objective: To get tweets of the user
    Input Parameter: api - object of class API
    Return Value: None
    '''
    print('\nTweets: ')
    for tweet in api.user_timeline():
        print(tweet.text)

def main():
    '''
    Objective: To print user information
    Input Parameter: None
    Return Value: None
    '''
    api = OAuthVerifier()
    getUserFollowers(api)
    getUserFriends(api)
    getUserTweets(api)

if __name__ == '__main__':
    main()
# Out:
# Followers:
# 02tyagi
# _Ghanesh_
# PeaceAlwaysPARI
# ikindlebook
#
# Friends:
# gvanrossum
# iamsrk_sharukh
# DataSciFact
# CompSciFact
# Delhi_U
# htTweets
# ndtv
# timesofindia
# EconomicTimes
# msdhoni
# BeingSalmanKhan
# SrBachchan
# imVkohli
# sachin_rt
# PythonHub
# PythonStack
# pycoders
# stonebirdgames
# djangoproject
# ThePSF
#
# Tweets:
# RT @gvanrossum: The very first https://t.co/2j12YXhlJD home page, from May 1997: https://t.co/KwtE7rjX9P
# RT @gvanrossum: MicroPython 1.7 released! Now with cross-compiler. https://t.co/gWq50gVEwk Congrats Damien and contributors!
# Hello Twitter! #myfirstTweet

# %% [markdown]
# ## <font color= blue > Collecting Tweets Having Specific Words </font>

# %% [markdown]
# * **StreamListener class**: used for collecting streaming tweets.
# * Class MyStreamListener inherits the class StreamListener of the tweepy module.
# * In the class MyStreamListener, we define two methods: on_status and on_error.
#
#         * The method on_status tells what to do when a status (input parameter)
#           known as tweet update is received.
#         * The method on_error handles the error and gets automatically invoked
#           on occurrence of an error.

# %%
import tweepy


class MyStreamListener(tweepy.StreamListener):
    # Class inheriting StreamListener of tweepy module

    def on_status(self, status):
        '''
        Objective: To print text stream of tweets
        Input Parameters:
            self (implicit parameter) - object of type
            MyStreamListener
            status - string value representing tweet
        Return Value: None
        '''
        print(status.text)
    
    def on_error(self, status):
        '''
        Objective: To disconnect the stream by returning False
        if error 420 occurs
        Input Parameters:
            self (implicit parameter) - object of type
            MyStreamListener
            status - int value representing error code
        Return Value: result - int
        '''
        if status==420:
            return False

def main():
    '''
    Objective: To print streaming data containing given keywords
    Input Parameter: None
    Return Value: None
    '''
    api = OAuthVerifier()
    # Creates a stream listener object listenerOb
    listenerOb = MyStreamListener()
    # Create a Stream object
    myStream = tweepy.Stream(api.auth, listenerOb)
    # Starts streaming by specifying search keywords
    searchList = eval(input('Enter search keywords list: '))
    myStream.filter(track = searchList)

if __name__ == '__main__':
    main()
# Out:
# Enter search keywords list: ['Python','Programming']
# RT @Ronald_vanLoon: Best #Python modules for #datamining
# by @kdnuggets |
#
# Read more at https://t.co/LTvov2H2AV
#
# #MachineLearning #ML #NLP #…
# #PHP no es como lo pintan.
#
# Dale una oportunidad y desarrolla utilizado este lenguaje de programación.… https://t.co/Dgl55DnVoF
# I do wish @TVCCfamily @TRatTVCC did not close during #Marchbreak and had activities for #disabled kids. The pool, f… https://t.co/Tb3HeDp3Rm
# RT @krassenstein: Viacom's MTV, Nickelodeon, BET and Comedy Central have all just suspended programming for 17 minutes in support of a nati…
# How to Program and Control an Arduino With Python #PrescientInfo #News https://t.co/CNHrBr2ITE
# RT @IBMSystems: "With machine learning, IT professionals are no longer programming the machine; instead they are training it to find adequa…
# RT @gem_hazard: Just published SRL paper explaining how python is becoming a common programming language in computational seismology https:…
# ぐぬぬ
# 【プログラミング学習のProgate】Pythonのレベルが5にUPしました！ https://t.co/ZRwtVpKsT0 #Progate
# marsh1962 : From Robot Design Automation to Life Design Automation - https://t.co/RKkiXmyFBo Designer Morphs: The C… https://t.co/5xkJh72862
# RT: Floris United Methodist Church for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/y6BOSkBqKa
# It’s unfair to compare network to basic/ premium cable, which Amazon and Netflix are more tied to. 8 million viewer… https://t.co/iJMfI6zGH6
# RT @GeneraGames: NUEVA VACANTE: PRÁCTICAS PROGRAMACIÓN PYTHON. Buscamos un estudiante que desee formarse con nosotros. Más información: htt…
# RT: Sully Station II Community Association for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/06PXj3zDVz
# RT @Sarah_May1: Hey @BBCPolitics you know that universities have value outside marketisation of degrees, that's why @bbc has so many senior…
# RT: Greenbriar Community Center for #STEM #Classes #Designing #Legos #Programming #Modeling #Kids #Education 🕰️🖥️🎮💎 https://t.co/WkOyVCXRJy
# So I didn't get anything in the last sessions with #python, so let's start from the beginning #learntocode #udacity
# RT @lefthandonright: I give free training on Data Science just coz i love it.
# Basic Statistics. Advanced #Analytics  methods.
# #R fundamen…
# RT: Camelot ES #CamelotFCPS #Elementary for #Programming #MinecraftModding at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/kMgqyPBf8A
# RT @BurlingtonEcDev: Do you know any kids aged 7-17 interested in Coding, Gaming, JavaScript and Robotics? Check out @codifyzone Info Sessi…
# RT: Southgate Community Center for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/AQkmv26bxk
# RT: #STEM #Classes #Designing #Legos #Programming #Modeling #Kids #Education 🕰️🖥️🎮💎 at Royal Cyber Club https://t.co/4VmWW7kz2h
# RT @krassenstein: Viacom's MTV, Nickelodeon, BET and Comedy Central have all just suspended programming for 17 minutes in support of a nati…
# RT @endcuttinggirls: It's time to #endcuttinggirls.
#
# Join the conversation as welcome our anchors. https://t.co/AhdfaKpttx
# @cheechablunt @Nickelodeon You're pissed off about 17 minutes of a f'ing cartoon, but fine with 17 children's lives… https://t.co/hOrcfoSL4s
# PROGRAMMING NOTE: Our noon and 6 p.m. newscasts will be preempted today due to CBS coverage of the… https://t.co/cHZPVsBdnl
# Thaïlande : Il découvre un énorme python dans le mur de son salon (vidéo) https://t.co/oD0R6QnCGK
# @python NowTime: 2018/03/16 01:49:33.2331
# TweetCount: 175
# RT @blue439: "Amazon’s U.S. audience for all video programming on Prime... was about 26 million customers... from late 2014 to early 2017."…
# RT: #STEM #Robotics #Programming #Modeling #STEMCamps #Kids #Education 🕰️🖥️🎮💎 at Royal Cyber Club https://t.co/MrCDKVXwm4
# RT @programmingurus: RT netbeans: Hello World, JDK 10 var! https://t.co/kfkbAV92mu #oracle #ObjectOriented#programming #Programmer #Java #j…
# RT: Cub Run ES #CubRunES #Elementary #School for 3D Game Programming (1-6th Grade) @ STEM Camp 🕰️🖥️🎮💎 https://t.co/rvHWFK89Im
# Today at 1:45 pm on WGCU-FM's #GCL, the #Florida Legislature’s newly approved #budget includes severe cuts to cultu… https://t.co/YqNIYN8N0b
# RT @krassenstein: Viacom's MTV, Nickelodeon, BET and Comedy Central have all just suspended programming for 17 minutes in support of a nati…
# #Google Maps une nouvelle #API qui va permettre aux développeurs de créer de nouveaux jeux AR et d’y intégrer des é… https://t.co/1vQR5woT1z
# Qualcomm and Google Plan to Work together..  #javascript #Python https://t.co/5BubONBtkB
# @dridk @BioinfoFr Y a une référence a Python 2 dans la doc c'est disqualifiant :) https://t.co/SSL30Ja3Ui
# RT @KCTV5: PROGRAMMING NOTE: Our noon and 6 p.m. newscasts will be preempted today due to CBS coverage of the #2018NCAABasketballTournament…
# Требуется написать программу, которая найдет сумму максимума из чисел с четными... https://t.co/TvGZotgVhI  #php… https://t.co/ALf9cfQhe9
# The latest The #Delphi Daily! https://t.co/CFQF09lgJB #regtech
# RT @krassenstein: Viacom's MTV, Nickelodeon, BET and Comedy Central have all just suspended programming for 17 minutes in support of a nati…
# RT @krassenstein: Viacom's MTV, Nickelodeon, BET and Comedy Central have all just suspended programming for 17 minutes in support of a nati…
# RT: Herndon Community Center for #STEM #Robotics #Programming #Modeling #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/XSxNW3dxjI
# RT @EntCareersNet: Crew Jobs: Pls Like, rt, or tag someone that would be a good fit. Part-Time Board Operator - New York - Operates the aud…
# @cascadianrhythm lol PD was how i first learned programming :D
# RT @kbari12: Donna Brazille  TODD MECKLER  PODESTA  Meeting w SOROS abour=t PRE PROGRAMMING VOTER MACHINES!!!!! 911 911 @TheJusticeDept @PO…
# 3 excellent programming tips to write faster, more efficient #code
# https://t.co/CLprmtZjXj
# ---
# #programming #dev #coding #development
# RT: Aldrin ES #AldrinEagles #Elementary #School for #Robotics #Programming at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/NrkN3hybHh
# RT: Aldrin ES #AldrinEagles #Elementary for #Programming #MinecraftModding at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/JwHeR0DLAm
# Full Stack Developer: We are looking for an experienced developer to help build out our Python backend and Javascri… https://t.co/zPJmdk5pGR
# RT: London Towne ES #LondonTowneFCPS #Elementary #School for 3D Game Programming (1-6th Grade) @ STEM Summer Camp… https://t.co/wxBzOZDVif
# Reddit/p: 0.2.0 Release Notes · The Zig Programming Language https://t.co/yZELhAXW7A
# RT: Chesterbrook ES #ChesterbrookES #Elementary #School for 3D Game Programming (1-6th Grade) @ STEM Summer Camp 🕰️… https://t.co/5keE3BkF0y
# RT @EqualToken: Congratulations to @contestsinkie for completing the programming challenge, revealing the private key and finding 75,000 $E…
# RT: Southgate Community Center for #STEM #Classes #Designing #Legos #Programming #Modeling #Kids #Education 🕰️🖥️🎮💎 https://t.co/FQaRJqRkH1
# RT: Greenbriar Community Center for #Robotics #Programming Educational Classes For Kids 🕰️🖥️🎮💎 https://t.co/Xqny8Hsgzg
# RT @KirkDBorne: Selected Recent #DataScience Articles from Top @DataScienceCtrl Contributors — Part 7: https://t.co/SY5qlqrgWm #abdsc #BigD…
# RT: Lord of Life Lutheran Church for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/OFEVlCL6j3
# RT @kylegriffin1: Television channels owned by Viacom—including MTV, BET, Nickelodeon, and Comedy Central—took a stance in support of #Nati…
# It's #NationalSocialWorkMonth, meet Bryn who develops and facilitates recreation and creative programming at Eva’s… https://t.co/assjL5Bw9r
# Cadeau : un script python pour afficher les personnes qui ont changé leur mot de passe depuis une certaine date.
#
# C… https://t.co/jH96G6IW45
# RT @EBMorelia: Clutch #3
# Axanthic Papuan Carpet Python x Granite Papuan Carpet Python.
# Double het for axanthic granite.#carpetpythons #carp…
# RT @platzi: La historia de Python como lenguaje de programación inicia a finales de los 80s y principios de los 90s con Guido Van Rossum, u…
# RT @KCTV5: PROGRAMMING NOTE: Our noon and 6 p.m. newscasts will be preempted today due to CBS coverage of the #2018NCAABasketballTournament…
# Happening now: How does Social Justice for People of Color inform transportation planning, programming, and design?… https://t.co/ObNBFPbFph
# Grow your team by focusing on strengths not weaknesses https://t.co/7jblLYsWsd #agile #scrum #pmot… https://t.co/Ut4zUd5rSR
# Today from 10am-5pm head to Halls Library for the study hours competition and then head over to the Student Center… https://t.co/ePCQ3wqBWi
# RT @Learyt_Tekuzo: I wrote a #gamemakerstudio2 tutorial for modifying the @ZackBellGames simple lighting system into covering just the view…
# RT: Lord of Life Lutheran Church for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/kyki1ngKdd
# RT @BAMSFest: We're making our mark on #Boston! Learn more about our programming and how you can support here: https://t.co/qZipcz5AGv http…
# RT @gp_pulipaka: #ApacheSpark - Summary. #BigData #MachineLearning #DataScience #AI #RStats #RLang #SparkSQL #Python #Hadoop #MapReduce #Ja…
# RT: Camelot ES #CamelotFCPS #Elementary #School for #Robotics #Programming at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/49fJBFEwsU
# RT @kattyuu01: ホーキング博士の歌う「銀河の歌」はiTunesで買えますので皆様是非。
# 「科学的に正しくない」と突っ込んだ物理学者を「学者ぶるな小僧」と車椅子でハネたあの曲です https://t.co/WfXOL5ZVxz https://t.co/5gRCnW…
# Projects in Node.js - Learn by Example
#
# ☞ https://t.co/hA3HkXLI2L
#
# #nodejs #programming https://t.co/kpMHXpFUwV
# RT: Southgate Community Center for #STEM #Classes #Designing #Legos #Programming #Modeling #Kids #Education 🕰️🖥️🎮💎 https://t.co/VhX7H3i8oI
# python is also like scala. has very nice syntax. feels like coding erlang web project. i liked python also.
# The latest The #Golang Go Programming #Gopher Daily! https://t.co/5jrspDRhlN Thanks to @cool_golang @MO2ndDist4Chg #reddit
# RT @edXOnline: Learn the basics of computational thinking, an essential skill in today’s data-driven world, using Python. Start today: http…
# RT: Greenbriar West ES #GBW_ES #Elementary #School for 3D Game Programming (1-6th Grade) @ STEM Summer Camp 🕰️🖥️🎮💎 https://t.co/h21CRIOtVV
# RT @meanroel: A little St. Patrick's day stem fun for the kids!  The computer programming game was a hit! I see that purchase in their futu…
# RT @TRANQUIL_IT: Cadeau : un script python pour afficher les personnes qui ont changé leur mot de passe depuis une certaine date.
#
# C'est fo…
# RT @RedTRaccoon: It's official.
#
# Our President is the french guy from Monty Python and the Holy Grail. https://t.co/j3Ofa0yATN
# RT @thestreettrust: Happening now: How does Social Justice for People of Color inform transportation planning, programming, and design? #at…
# RT @KirkDBorne: Naive Bayes Classification explained with #Python code: https://t.co/9i8Mvxd9SG #abdsc #BigData #DataScience #MachineLearni…
# Violent Python shows you how to move from a theoretical understand https://t.co/cC6n1DV0Ub #Cybersecurity #Bitcoin https://t.co/EvqRWRZID0
# RT: Cub Run ES #CubRunES #Elementary #School for #Robotics #Programming at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/SNlXTMuvAJ
# Violent Python shows you how to move from a theoretical understand https://t.co/xlFmLy0WLU #Cybersecurity #Bitcoin https://t.co/uV8Pr3HXMt
# @Vtechp @welltraveledfox @AP You do know Oliver is a comedy show, not reality television?
#
# Also, you do know that t… https://t.co/HnzX1stymP
# RT @kbari12: Got it!!!! @realDonaldTrump @WhiteHouse SOROS PRE PROGRAMMING VOTING MACHINES @TheJusticeDept @jeffsessions @DeptofDefense @US…
# RT @kylegriffin1: Television channels owned by Viacom—including MTV, BET, Nickelodeon, and Comedy Central—took a stance in support of #Nati…
# Today from 10am-5pm head to Halle Library for the study hours competition and then head over to the Student Center… https://t.co/1IriCkW2u7
# RT @KCTV5: PROGRAMMING NOTE: Our noon and 6 p.m. newscasts will be preempted today due to CBS coverage of the #2018NCAABasketballTournament…
# sismic 0.26.2: Sismic Interactive Statechart Model Interpreter and Checker https://t.co/LLvRWefWao
# Moustache.beta 0.0.1.post16647: Module Moustache pour fusion ODT https://t.co/HbBcREF8mo
# RT: Fairfax Presbyterian Church for #Robotics #Programming #Modeling #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/b47KfpM38J
# hassmart-homeassistant 0.65.4: Open-source home automation platform r... https://t.co/Tam9baNxIO
# Noooooooooooooooooooope https://t.co/2jygnuU6Gt
# page-object 0.3.2: Python implementation of the PageObject pattern https://t.co/FgkPK2rqOz
# google-api-core 1.1.0: Google API client core library https://t.co/Eh9yG2i6pB
# 流行ってるだけあって本も多くていいねPython
# We're so grateful to @talkboxbooth for donating 1% equity to VFA to support our programming! https://t.co/IrpdeZFr54
# Once upon a time, C the awesome programming language set out for adventures. C went home.
# RT @inscapetv: #ThisIsUs got a major viewership boost from the post-Super Bowl episode: 49% of the audience watching This Is Us on #SuperBo…
# RT @edXOnline: Learn the basics of computational thinking, an essential skill in today’s data-driven world, using Python. Start today: http…
# RT: McNair ES #FCPSMcNairES #Elementary for #Programming #MinecraftModding at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/TP3hsHsmKJ
# RT: Greenbriar West ES #GBW_ES #Elementary for #Programming #MinecraftModding at Royal Cyber Club 🕰️🖥️🎮💎 https://t.co/p66BoUo76T
# Python Programming: An In-Depth Guide Into The Essentials Of Python Programming https://t.co/JL5nMm4GnW
# Projects in Node.js - Learn by Example
#
# ☞ https://t.co/FTz42xc1W9
#
# #nodejs #programming https://t.co/BmCmIVQ5SO
# RT @dareadaramoye: 10. UNFPA &amp; UNICEF have over the past years refocused attention on harmful traditional practices, with specific referenc…
# A #scikit compatible #python package for multivariate time-series segmentation, feature extraction, forecasting and… https://t.co/h5F2LV7Zxw
# RT: Greenbriar Community Center for #Programming cool games #STEMCamps #Kids #Education 🕰️🖥️🎮💎 https://t.co/PJf3w32Wf9
# #GIS Q&amp;A: python script opens up mxds to remove specific group layer error https://t.co/JushsDoCJx https://t.co/wtJu0JrOQP
# There’s a special place in hell for people who insist on internal programming commercials being overtly related to… https://t.co/QodVVeLdp2
# This year I have a goal - to work on stopping negative, bad programming/thinking in my head, stop being self-deprec… https://t.co/qORPV2JvRK
